# %%
import pandas as pd
import random
import os

# Define our categories
CATEGORIES = ["sexism", "racism", "violence", "appearance", "ability", "non-offensive"]

def create_multi_label_tool(data_path, output_file, num_samples=100):
    """Tool to help manually label comments with multiple labels"""
    # Load the data
    df = pd.read_csv(data_path)
    
    # Check what column contains the comments
    print(f"Columns in your dataset: {df.columns.tolist()}")
    
    # Ask for the column name
    text_column = input(f"Which column contains the comments? Enter a name from above: ")
    
    if text_column not in df.columns:
        print(f"Error: Column '{text_column}' not found.")
        return
    
    # Select random samples
    if len(df) > num_samples:
        sample_df = df.sample(num_samples, random_state=42)
    else:
        sample_df = df
    
    # Create a new dataframe for labels
    labeled_df = pd.DataFrame({
        'comment': sample_df[text_column]
    })
    
    # Add columns for each category (1 for selected, 0 for not selected)
    for category in CATEGORIES:
        labeled_df[category] = 0
    
    # Add a column to track if this comment has been labeled
    labeled_df['is_labeled'] = False
    
    # Check if output file exists
    if os.path.exists(output_file):
        existing_df = pd.read_csv(output_file)
        print(f"Found existing labeled data with {len(existing_df)} entries.")
        
        # Make sure all category columns exist in the existing data
        for category in CATEGORIES:
            if category not in existing_df.columns:
                existing_df[category] = 0
        
        # Add 'is_labeled' column if it doesn't exist
        if 'is_labeled' not in existing_df.columns:
            existing_df['is_labeled'] = existing_df[CATEGORIES].sum(axis=1) > 0
        
        # Add only new comments
        existing_comments = set(existing_df['comment'].tolist())
        new_comments = [comment for comment in labeled_df['comment'] if comment not in existing_comments]
        
        if new_comments:
            new_df = pd.DataFrame({'comment': new_comments})
            for category in CATEGORIES:
                new_df[category] = 0
            new_df['is_labeled'] = False
            labeled_df = pd.concat([existing_df, new_df], ignore_index=True)
        else:
            labeled_df = existing_df
            print("No new comments to label.")
    
    # Interactive labeling
    for idx, row in labeled_df.iterrows():
        # Skip if already labeled
        if row['is_labeled']:
            continue
        
        # Display the comment
        print("\n" + "="*80)
        print(f"Comment {idx+1}/{len(labeled_df)}:")
        print(row['comment'])
        print("="*80)
        
        # Show category options
        print("\nCategories (select multiple by entering numbers separated by spaces):")
        for i, category in enumerate(CATEGORIES):
            print(f"{i+1}. {category}")
        
        # Get labels
        while True:
            choice = input("\nEnter category numbers (or 's' to skip, 'q' to quit): ")
            
            if choice.lower() == 'q':
                labeled_df.to_csv(output_file, index=False)
                print(f"Progress saved to {output_file}.")
                print(f"Labeled {labeled_df['is_labeled'].sum()} comments.")
                return
            
            if choice.lower() == 's':
                break
            
            try:
                # Parse multiple selections
                selections = [int(num) for num in choice.split()]
                valid_selections = all(1 <= num <= len(CATEGORIES) for num in selections)
                
                if valid_selections:
                    # Reset all categories for this comment
                    for category in CATEGORIES:
                        labeled_df.at[idx, category] = 0
                    
                    # Set the selected categories
                    for num in selections:
                        category = CATEGORIES[num-1]
                        labeled_df.at[idx, category] = 1
                    
                    # Mark as labeled
                    labeled_df.at[idx, 'is_labeled'] = True
                    break
                else:
                    print(f"Invalid choice. Please enter numbers between 1 and {len(CATEGORIES)}.")
            except ValueError:
                print("Please enter numbers separated by spaces, 's', or 'q'.")
        
        # Save progress after each label
        labeled_df.to_csv(output_file, index=False)
    
    # Final save
    labeled_df.to_csv(output_file, index=False)
    print(f"Labeling complete! Saved to {output_file}")
    print(f"Labeled {labeled_df['is_labeled'].sum()} comments.")
    
    # Ask if user wants to merge labels back to original dataset
    merge_choice = input("\nDo you want to merge the labels back to the original dataset? (y/n): ")
    if merge_choice.lower() == 'y':
        merge_labels_with_original(df, labeled_df, text_column, data_path)

def merge_labels_with_original(original_df, labeled_df, text_column, original_path):
    """Merge the labeled data back into the original dataset"""
    # Create output filename
    base_name = os.path.splitext(original_path)[0]
    merged_path = f"{base_name}_with_labels.csv"
    
    print("\nMerging labeled data with original dataset...")
    
    # Create a mapping of comments to their labels
    label_dict = {}
    for _, row in labeled_df.iterrows():
        if row['is_labeled']:
            label_dict[row['comment']] = {cat: row[cat] for cat in CATEGORIES}
    
    # Add label columns to original dataframe
    for category in CATEGORIES:
        original_df[category] = 0
    
    # Fill in labels where they exist
    labeled_count = 0
    for idx, row in original_df.iterrows():
        comment = row[text_column]
        if comment in label_dict:
            for category in CATEGORIES:
                original_df.at[idx, category] = label_dict[comment][category]
            labeled_count += 1
    
    # Save the merged dataset
    original_df.to_csv(merged_path, index=False)
    print(f"\nMerged dataset saved to {merged_path}")
    print(f"Added labels for {labeled_count} out of {len(original_df)} comments.")

if __name__ == "__main__":
    data_path = input("Enter the path to your dataset CSV file: ")
    output_file = input("Enter the path for saving labeled data (e.g., labeled_data.csv): ")
    num_samples = int(input("How many comments do you want to label? "))
    
    create_multi_label_tool(data_path, output_file, num_samples)
# Out:
# Columns in your dataset: ['Unnamed: 0', 'name', 'demographic', 'video_id', 'comment', 'author', 'like_count', 'published_at']
#
# ================================================================================
# Comment 1/75:
# Ronaldo is Tough, not like messy
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 2/75:
# But both are still goats
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 3/75:
# BRUH THIS IS FAKE
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 4/75:
# Ewww
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 5/75:
# A kid will fight over any thing
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 6/75:
# ronaldo is the goat
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 7/75:
# This is faker than my imaginery friend.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 8/75:
# Messi never laughed at ronaldo and he just used clips from complete different matches and the fouls were by accident by ronaldo
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 9/75:
# Messi your doing wrong
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 10/75:
# Team Messi here 👇
# Never mess with Messi
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 11/75:
# Ronaldo's a goat 🔥🔥
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 12/75:
# RONALDO IS THE BEST
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 13/75:
# poor RONALDO😭😭😭!
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 14/75:
# Haaland goal was crazy
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 15/75:
# awesome, great video
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 16/75:
# 1 million in 1000000 😂😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 17/75:
# Bro I love your content I watch every video and I hope u reach 6million subscribers ❤😊
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 18/75:
# the 30th person who liked this video 😁
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 19/75:
# 🇮🇶🇮🇶
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 20/75:
# SUBSCRIBE NOW I SUSCRÍBETE ► https://www.youtube.com/fcbarcelona 🔵🔴
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 21/75:
# JUSTICE always win
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 22/75:
# 뤼디거는 저런 실수해도 욕을 안먹고 민재는 욕 바가지고 먹네
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 23/75:
# Mickey mouse cup 🥀💔
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 24/75:
# 💙❤️💯🔵🔴
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 25/75:
# Valverde☠️☠️☠️☠️☠️☠️☠️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 26/75:
# The worst thing is they call them "tactical fouls" and most football followers accept them, "as long as it's not red card, or even if it is, it's better that than loosing". Like what the actual fuck. Even the trainers encourage their players to commit them🤮🤮
#
# For me this is fucking disgusting,dangerous for the players (their career can literaly end and and have serious injuries), and an insult to sportmanship and fair play.
#
# Me myself have an anckle sprain just because of a fucking random guy, who could be my father, who commited a "technical foul" on me just because I'm good (i had scored already 2 goals, both nutmeging the keeper by the way)
#
# IT'S NOT FAIR
#
# By the way I'm a referee now and at the minimal foul like this I swear, it can be technically a yellow card, but if it's done out of the blue and without justification I will pull red card. Don't care if I loose my job or am critizised. Sportmanship above all, in football as well. You can change thing like that maybe, or the other way from the inside, reaching the high spheres of refereeing and changing rules.🤷 the second one seems less plausible so I'll just take justice in my own hands.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 27/75:
# ‏دائما لما العب Fortnite يجلدون أخوياي بعد ما يحط ميوت اصير لعيب و ميقدرون عليه
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 28/75:
# Комментатор кричал ломай его федяяяя
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 29/75:
# 😂😂😂😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 30/75:
# Why do editors insist on having this horrible music in every video?
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 31/75:
# Simeone respected bro
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 32/75:
# Good
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 33/75:
# Simeone: Next season you will be mine.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 34/75:
# I love someone in this second
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 35/75:
# Simeone knows that he had no choice goal or tackle 🤣
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 36/75:
# Solskajer beşiktaşın manageri değilmi
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 37/75:
# This is so real😂❤️ and also love ur content❤️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 38/75:
# i unfortunately admit, that happens to be me. at least we don't have to do drills🤷‍♀️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 39/75:
# Um so this is literally me lol! I tore my acl and meniscus just taking off to run in a game, and i tore something in my hip last fall just taking a kick...💀 im not allowed to play my sophmore season and i missed the whole freshman season from the hip injury, so my skills are cooked. ☹️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 40/75:
# She tore the abcdefghijklmnopqrstuvwxyzCL 😂😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 41/75:
# not all the cl’s 😭☠️🤞
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 42/75:
# Niceee
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 43/75:
# Carvajal cooked mertens 🔥
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 44/75:
# The confidence and skills and leadership on the pitch is so UnderRated..6 times UCL..it speaks volumes...😮😮..
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 45/75:
# W Pepe
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 46/75:
# Hi
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 47/75:
# Pepe  was like get it
#
#
#
#  Carvajal  It
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 48/75:
# Bro make football edits too, I just started but am not getting that much vies and subs please pin me
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 49/75:
# Pepe the young man❤
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 50/75:
# Me and my friend on the same team be like
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 51/75:
# ❤❤
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 52/75:
# Mbappe
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 53/75:
# 🔥🔥
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 54/75:
# jala
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 55/75:
# Pepe with Carvajal
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 56/75:
# [4-4 19:25] j: Mario fernandes
# [4-4 19:25] j: Abate
# [4-4 19:25] j: Maxi pereira
# [4-4 19:25] j: Cri zapata
# [4-4 19:25] j: Hugo campagnaro
# [4-4 19:26] j: Mexes
# [4-4 19:26] j: Mathijssen
# [4-4 19:26] j: Vitorbaia
# [4-4 19:26] j: Isaksson
# [4-4 19:26] j: Jahilka
# [4-4 19:26] j: Edmilson
# [4-4 19:26] j: Maxwell
# [4-4 19:26] j: Fabioaurelio
# [4-4 19:26] j: Aldair
# [4-4 19:26] j: Juniormalnda
# [4-4 19:26] j: Cheicktiote
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 57/75:
# Mertens baba mı o?
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 58/75:
# 😮
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 59/75:
# Федос❤
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 60/75:
# Marcelo😂😂😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 61/75:
# Thats my frien jean carlos one day I blocked a shot an the he stared in shock and threw himself like the last one
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 62/75:
# I don’t get Marcelo something pls help me understand
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 63/75:
# The last one is crazy
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 64/75:
# Top worse injuries in football
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 65/75:
# Robaldo😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 66/75:
# америкосы не знают ласт😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 67/75:
# https://www.youtube.com/@Ur.carstaino
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 68/75:
# The last one probably Neymar or Icardi😅
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 69/75:
# SONDAKİ LUCAS TORREİRA VEYA DRİES MERTENS
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 70/75:
# CAN YOU PIN ME FOOTBOLL_ABN7
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 71/75:
# second last didnt do on purpose
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 72/75:
# Gs
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 73/75:
# Cristiano 😂
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 74/75:
# The last one is the best
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 75/75:
# Courtios is now play for real madrid
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
# Labeling complete! Saved to labeled_male.csv
# Labeled 61 comments.
#
# Merging labeled data with original dataset...
#
# Merged dataset saved to merged_output_male_with_labels.csv
# Added labels for 61 out of 75 comments.
