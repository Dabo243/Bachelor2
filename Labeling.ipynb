# %%
import pandas as pd
import random
import os

# Define our categories
CATEGORIES = ["sexism", "racism", "violence", "appearance", "ability", "non-offensive"]

def create_multi_label_tool(data_path, output_file, num_samples=100):
    """Tool to help manually label comments with multiple labels"""
    # Load the data
    df = pd.read_csv(data_path)
    
    # Check what column contains the comments
    print(f"Columns in your dataset: {df.columns.tolist()}")
    
    # Ask for the column name
    text_column = input(f"Which column contains the comments? Enter a name from above: ")
    
    if text_column not in df.columns:
        print(f"Error: Column '{text_column}' not found.")
        return
    
    # Select random samples
    if len(df) > num_samples:
        sample_df = df.sample(num_samples, random_state=42)
    else:
        sample_df = df
    
    # Create a new dataframe for labels
    labeled_df = pd.DataFrame({
        'comment': sample_df[text_column]
    })
    
    # Add columns for each category (1 for selected, 0 for not selected)
    for category in CATEGORIES:
        labeled_df[category] = 0
    
    # Add a column to track if this comment has been labeled
    labeled_df['is_labeled'] = False
    
    # Check if output file exists
    if os.path.exists(output_file):
        existing_df = pd.read_csv(output_file)
        print(f"Found existing labeled data with {len(existing_df)} entries.")
        
        # Make sure all category columns exist in the existing data
        for category in CATEGORIES:
            if category not in existing_df.columns:
                existing_df[category] = 0
        
        # Add 'is_labeled' column if it doesn't exist
        if 'is_labeled' not in existing_df.columns:
            existing_df['is_labeled'] = existing_df[CATEGORIES].sum(axis=1) > 0
        
        # Add only new comments
        existing_comments = set(existing_df['comment'].tolist())
        new_comments = [comment for comment in labeled_df['comment'] if comment not in existing_comments]
        
        if new_comments:
            new_df = pd.DataFrame({'comment': new_comments})
            for category in CATEGORIES:
                new_df[category] = 0
            new_df['is_labeled'] = False
            labeled_df = pd.concat([existing_df, new_df], ignore_index=True)
        else:
            labeled_df = existing_df
            print("No new comments to label.")
    
    # Interactive labeling
    for idx, row in labeled_df.iterrows():
        # Skip if already labeled
        if row['is_labeled']:
            continue
        
        # Display the comment
        print("\n" + "="*80)
        print(f"Comment {idx+1}/{len(labeled_df)}:")
        print(row['comment'])
        print("="*80)
        
        # Show category options
        print("\nCategories (select multiple by entering numbers separated by spaces):")
        for i, category in enumerate(CATEGORIES):
            print(f"{i+1}. {category}")
        
        # Get labels
        while True:
            choice = input("\nEnter category numbers (or 's' to skip, 'q' to quit): ")
            
            if choice.lower() == 'q':
                labeled_df.to_csv(output_file, index=False)
                print(f"Progress saved to {output_file}.")
                print(f"Labeled {labeled_df['is_labeled'].sum()} comments.")
                return
            
            if choice.lower() == 's':
                break
            
            try:
                # Parse multiple selections
                selections = [int(num) for num in choice.split()]
                valid_selections = all(1 <= num <= len(CATEGORIES) for num in selections)
                
                if valid_selections:
                    # Reset all categories for this comment
                    for category in CATEGORIES:
                        labeled_df.at[idx, category] = 0
                    
                    # Set the selected categories
                    for num in selections:
                        category = CATEGORIES[num-1]
                        labeled_df.at[idx, category] = 1
                    
                    # Mark as labeled
                    labeled_df.at[idx, 'is_labeled'] = True
                    break
                else:
                    print(f"Invalid choice. Please enter numbers between 1 and {len(CATEGORIES)}.")
            except ValueError:
                print("Please enter numbers separated by spaces, 's', or 'q'.")
        
        # Save progress after each label
        labeled_df.to_csv(output_file, index=False)
    
    # Final save
    labeled_df.to_csv(output_file, index=False)
    print(f"Labeling complete! Saved to {output_file}")
    print(f"Labeled {labeled_df['is_labeled'].sum()} comments.")

if __name__ == "__main__":
    data_path = input("Enter the path to your dataset CSV file: ")
    output_file = input("Enter the path for saving labeled data (e.g., labeled_data.csv): ")
    num_samples = int(input("How many comments do you want to label? "))
    
    create_multi_label_tool(data_path, output_file, num_samples)
# Out:
# Columns in your dataset: ['video_id', 'comment']
# Found existing labeled data with 100 entries.
#
# ================================================================================
# Comment 97/192:
# Stream full match DAZN, open all territories, look they all so wet 🥹
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 101/192:
# Brilliant 👍😊
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 102/192:
# I love them all, but I'm missing Caroline Graham Hansen's goal against Chelsea!
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 103/192:
# I definitely think they should make more these types of series for both the men and women games.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 104/192:
# Brilliant goal, brilliant match :)
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 105/192:
# The best football Shorts 🤞
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 106/192:
# If only the men could do as well! Brilliant team, can't wait to see what to come for the women 👏
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 107/192:
# Don't put the score in the title
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 108/192:
# The arsenal player at left wing is Tierney's female version
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 109/192:
# what a player what a nice video
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 110/192:
# why are Barca still putting Walsh on !!
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 111/192:
# To many ads on this match hard to watch
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 112/192:
# The ladys 2 goals are better than some mens goals. She is the number 1 best player for women in the world right now. Those goals are impossible
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 113/192:
# Congratulations 🎉🎉🎉
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 114/192:
# How was that a penalty Lyon was robbed
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 115/192:
# Robbery
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 116/192:
# Barça and comebacks
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 117/192:
# It was so so close, I'm so sad and angry
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 118/192:
# Arsenal women is a great team
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 119/192:
# Barca all the way!
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 120/192:
# Amazing performance 😍
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 121/192:
# Bayern kicked Barcelona to the moon and arsenal right after. UNSTOPPABLE. MIA SAN MIA
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 122/192:
# Well played....
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 123/192:
# Bonmati❤❤
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 124/192:
# Barcelona women all look like Messi from afar but when the camera zooms in you can clearly tell it’s a cutie there! 😅
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 125/192:
# Best of luck
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 126/192:
# Best game it
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 127/192:
# Perfect game
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 128/192:
# Great comeback! On PSG's 1st. goal, #26 Lindsey Horan was sleeping on the field, lol.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 129/192:
# Great performance from both team
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 130/192:
# WHAT A GAME,,WELL PLAYED ARSENAL
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 131/192:
# The 4-1: Mariona -> Vicky López -> Putellas -> Aitana -> Salma. Can't get any better than that.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 132/192:
# Attendance record trend started from here❤💙
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 133/192:
# congratulations to Barcelona become a champion of UWCL 2022/2023 and Manchester City become a champion of FA Cup 2023 .
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 134/192:
# This is so exciting...!!!
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 135/192:
# Disgusting pen, Chelsea totally bailed by the referee. They don't have the level for the semis, the other teams have been more consistent.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 136/192:
# UEFAlona making its comeback into the Europe once again
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 137/192:
# Nice kick to try the goal i like that😍
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 138/192:
# Looking forward
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 139/192:
# My left ear enjoyed this one 😅👍
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 140/192:
# This barca team is just not unstoppable
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 141/192:
# The girls did all we could've asked of them and then some. Eventually, it was just too much with all those injuries. The difference, in the end, was that the Germans, unlike us, had their biggest star back - Popp was vital with assisting the first and scoring the second.
# We need to learn to finish the games though. Those two goals conceded in overtime against United, the late equaliser by Kerr against Chelsea, and now this. Season defining moments.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 142/192:
# Brilliant goal
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 143/192:
# Mate give the music a F--cking rest
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 144/192:
# 🏆Barça Femeni🏆 Champions of Champions.💙❤️💙❤️💙❤️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 145/192:
# I mean gambling is so fun and fair, obv only Like gambling Situations where the question isnt If U win Just how much U win
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 146/192:
# The catalyst that changed the women's game was the 2015 Women's World Cup. Not this game. That WC, lead to the growth and popularity of the women's game that was able to lead to this Barca record, england record etc. Sponsors and broadcasting are still a very big challenge to watch regular season games that aren't quarter/semi/finals matches.
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment 147/192:
# Is this Neddy Anderson enlightening us on every conceivable
#  fragment of WSL/UEFA
# trivia❓️He's a fountain of distraction in 2025 .
# WSL needs an "on mike academy" so as to eventually eliminate the verbal diarrhoea  . PUH -- LEEZE❗️❗️❗️❗️❗️
# ================================================================================
#
# Categories (select multiple by entering numbers separated by spaces):
# 1. sexism
# 2. racism
# 3. violence
# 4. appearance
# 5. ability
# 6. non-offensive
#
# ================================================================================
# Comment